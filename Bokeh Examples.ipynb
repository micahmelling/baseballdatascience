# %%
#Import libraries
from bs4 import BeautifulSoup
import requests
import pandas as pd
import numpy as np

# %%
#Use requests library to get the URL
r  = requests.get("http://www.baseball-reference.com/teams/tgl.cgi?team=KCR&t=b&year=2016")
data = r.text

# %%
#Create beautiful soup object from the data
soup = BeautifulSoup(data)
# Out:
# C:\Users\E036900\AppData\Local\Continuum\Anaconda3\lib\site-packages\bs4\__init__.py:166: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# To get rid of this warning, change this:
#
#  BeautifulSoup([your markup])
#
# to this:
#
#  BeautifulSoup([your markup], "lxml")
#
#   markup_type=markup_type))

# %%
#Extract column headers
column_headers = [th.getText() for th in 
                  soup.findAll('tr', limit=2)[0].findAll('th')]

# %%
#Define data rows
data_rows = soup.findAll('tr')

# %%
#Get data from table
team_data = [[td.getText() for td in data_rows[i].findAll('td')]
            for i in range(len(data_rows))]

# %%
#Convert to data frame
df = pd.DataFrame(team_data, columns = column_headers)
print(df)
# Out:
#        Rk   Gtm    Date         Opp    Rslt    PA    AB     R     H  \
# 0    None  None    None  None  None    None  None  None  None  None
# 1       1     1   Apr 3         NYM   W,4-3    33    30     4     9
# 2       2     2   Apr 5         NYM   L,0-2    32    31     0     3
# 3       3     3   Apr 8         MIN   W,4-3    37    32     4     9
# 4       4     4   Apr 9         MIN   W,7-0    40    35     7    10
# 5       5     5  Apr 10         MIN   W,4-3    38    35     4     7
# 6       6     6  Apr 11     @   HOU   L,2-8    38    37     2    11
# 7       7     7  Apr 12     @   HOU   W,3-2    35    33     3     7
# 8       8     8  Apr 13     @   HOU   W,4-2    38    35     4     8
# 9       9     9  Apr 14     @   HOU   W,6-2    40    39     6    13
# 10     10    10  Apr 15     @   OAK   W,4-2    42    37     4    12
# 11     11    11  Apr 16     @   OAK   L,3-5    38    36     3     9
# 12     12    12  Apr 17     @   OAK   L,2-3    35    33     2     6
# 13     13    13  Apr 19         DET   W,8-6    37    32     8     9
# 14     14    14  Apr 20         DET   L,2-3    38    35     2    10
# 15     15    15  Apr 21         DET   W,4-0    36    29     4    10
# 16     16    16  Apr 22         BAL   W,4-2    32    31     4     8
# 17     17    17  Apr 23         BAL   L,3-8    35    34     3     7
# 18     18    18  Apr 24         BAL   W,6-1    37    33     6    11
# 19     19    19  Apr 25     @   LAA   L,1-6    36    31     1     4
# 20     20    20  Apr 26     @   LAA   L,4-9    37    33     4     9
# 21     21    21  Apr 27     @   LAA   L,2-4    38    35     2    10
# 22     22    22  Apr 29     @   SEA   L,0-1    34    30     0     6
# 23     23    23  Apr 30     @   SEA   L,0-6    32    31     0     5
# 24   None  None    None  None  None    None  None  None  None  None
# 25     24    24   May 1     @   SEA   W,4-1    39    37     4    11
# 26     25    25   May 2         WSN   L,0-2    34    31     0     5
# 27     26    26   May 3         WSN   W,7-6    38    35     7    11
# 28     27    27   May 4         WSN  L,2-13    34    32     2     5
# 29     28    28   May 6     @   CLE   L,1-7    36    35     1     9
# ..    ...   ...     ...   ...   ...     ...   ...   ...   ...   ...
# 138  None  None    None  None  None    None  None  None  None  None
# 139   134   134   Sep 2         DET   L,6-7    41    39     6    11
# 140   135   135   Sep 3         DET   W,5-2    37    33     5     9
# 141   136   136   Sep 4         DET   L,5-6    37    32     5     7
# 142   137   137   Sep 5     @   MIN  W,11-5    46    39    11    16
# 143   138   138   Sep 6     @   MIN  W,10-3    42    36    10    10
# 144   139   139   Sep 7     @   MIN   L,5-6    38    35     5    11
# 145   140   140   Sep 9     @   CHW   L,2-7    39    35     2     7
# 146   141   141  Sep 10     @   CHW   W,6-5    38    33     6     7
# 147   142   142  Sep 11     @   CHW   W,2-0    38    36     2    10
# 148   143   143  Sep 12         OAK  L,3-16    35    33     3     7
# 149   144   144  Sep 13         OAK   L,4-5    39    37     4    10
# 150   145   145  Sep 14         OAK   L,0-8    33    30     0     4
# 151   146   146  Sep 15         OAK  L,5-14    37    35     5     9
# 152   147   147  Sep 16         CHW   L,4-7    35    34     4     7
# 153   148   148  Sep 17         CHW   W,3-2    31    29     3     7
# 154   149   149  Sep 18         CHW  W,10-3    40    35    10    12
# 155   150   150  Sep 19         CHW   W,8-3    39    36     8    12
# 156   151   151  Sep 20     @   CLE   L,1-2    32    31     1     6
# 157   152   152  Sep 21     @   CLE   L,3-4    35    32     3     7
# 158   153   153  Sep 22     @   CLE   L,2-5    34    32     2     6
# 159   154   154  Sep 23     @   DET   L,3-8    38    37     3    11
# 160   155   155  Sep 24     @   DET   W,7-4    41    37     7    10
# 161   156   156  Sep 25     @   DET  W,12-9    46    45    12    19
# 162   157   157  Sep 27         MIN   W,4-3    40    33     4     7
# 163   158   158  Sep 28         MIN   W,5-2    35    32     5     8
# 164   159   159  Sep 29         MIN   L,6-7    40    37     6    13
# 165   160   160  Sep 30         CLE   L,2-7    31    30     2     5
# 166   161   161   Oct 1         CLE   L,3-6    38    35     3     8
# 167   162   162   Oct 2         CLE   L,2-3    32    31     2     6
#
#             ...             SB    CS    BA   OBP   SLG   OPS   LOB     #  \
# 0           ...           None  None  None  None  None  None  None  None
# 1           ...              1     0  .300  .333  .300  .633     5     9
# 2           ...              1     0  .197  .231  .246  .477     5     9
# 3           ...              0     1  .226  .275  .301  .576     9     9
# 4           ...              0     0  .242  .303  .391  .693     9     9
# 5           ...              0     0  .233  .289  .387  .675     5    10
# 6           ...              0     0  .245  .294  .390  .684     9    11
# 7           ...              1     0  .240  .289  .382  .671     5     9
# 8           ...              0     0  .239  .285  .384  .670     7     9
# 9           ...              0     0  .251  .293  .397  .690     7    10
# 10          ...              1     0  .259  .306  .401  .707    11     9
# 11          ...              1     0  .258  .304  .387  .691     8    10
# 12          ...              1     0  .252  .298  .380  .678     6    10
# 13          ...              0     0  .254  .304  .387  .691     5     9
# 14          ...              2     1  .256  .307  .394  .701     9     9
# 15          ...              4     0  .261  .315  .401  .716     8     9
# 16          ...              0     1  .261  .313  .404  .717     4     9
# 17          ...              0     0  .258  .308  .401  .709     5     9
# 18          ...              0     0  .262  .313  .412  .724     7     9
# 19          ...              0     0  .255  .309  .400  .709     8     9
# 20          ...              0     0  .256  .311  .407  .718     6     9
# 21          ...              2     0  .258  .313  .407  .720     9     9
# 22          ...              4     1  .255  .311  .398  .709     7     9
# 23          ...              0     0  .252  .307  .390  .696     5     9
# 24          ...           None  None  None  None  None  None  None  None
# 25          ...              2     1  .254  .308  .391  .698     8     9
# 26          ...              0     1  .250  .305  .383  .688     7     9
# 27          ...              2     0  .253  .307  .380  .687     5    11
# 28          ...              0     0  .249  .303  .374  .677     5    13
# 29          ...              0     1  .250  .302  .369  .672     8     9
# ..          ...            ...   ...   ...   ...   ...   ...   ...   ...
# 138         ...           None  None  None  None  None  None  None  None
# 139         ...              2     1  .261  .312  .398  .710     8    10
# 140         ...              1     0  .261  .312  .398  .710     8    11
# 141         ...              1     1  .261  .312  .398  .710     5    12
# 142         ...              1     0  .262  .313  .400  .714     8    11
# 143         ...              3     0  .262  .314  .400  .715     5    13
# 144         ...              2     0  .263  .314  .402  .716     6    11
# 145         ...              3     0  .262  .314  .400  .714    10    10
# 146         ...              1     0  .262  .314  .400  .714     5    11
# 147         ...              0     0  .262  .314  .401  .715     9    10
# 148         ...              0     0  .262  .314  .400  .714     5    13
# 149         ...              2     0  .262  .314  .399  .713     8    10
# 150         ...              0     0  .261  .313  .398  .711     6     9
# 151         ...              0     0  .261  .313  .398  .711     5    14
# 152         ...              0     0  .261  .312  .397  .710     4    11
# 153         ...              2     0  .260  .312  .397  .709     4    10
# 154         ...              0     1  .261  .313  .399  .711     6    10
# 155         ...              3     0  .261  .313  .400  .713     7    11
# 156         ...              1     0  .261  .313  .400  .712     4    12
# 157         ...              0     2  .261  .312  .399  .712     5    10
# 158         ...              1     0  .260  .312  .399  .711     5     9
# 159         ...              0     0  .261  .312  .398  .710     8    11
# 160         ...              0     0  .261  .312  .399  .711     7    13
# 161         ...              4     0  .262  .313  .402  .715     7     9
# 162         ...              3     0  .262  .313  .401  .714     4    12
# 163         ...              1     0  .262  .313  .401  .714     6    10
# 164         ...              0     1  .262  .314  .402  .715     7    12
# 165         ...              0     0  .262  .313  .401  .714     2    11
# 166         ...              1     0  .262  .313  .400  .713     8     9
# 167         ...              0     1  .261  .312  .400  .712     3    12
#
#       Thr Opp. Starter (GmeSc)
# 0    None                 None
# 1       R        M.Harvey (39)
# 2       R   N.Syndergaard (74)
# 3       R       E.Santana (57)
# 4       L        T.Milone (47)
# 5       R       R.Nolasco (72)
# 6       R        C.McHugh (64)
# 7       R         M.Fiers (50)
# 8       R       S.Feldman (58)
# 9       R        D.Fister (29)
# 10      L          R.Hill (36)
# 11      R          S.Gray (57)
# 12      R       C.Bassitt (62)
# 13      R        S.Greene (21)
# 14      R    J.Zimmermann (66)
# 15      R       M.Pelfrey (34)
# 16      R      Y.Gallardo (29)
# 17      R        T.Wilson (45)
# 18      R        M.Wright (41)
# 19      R      G.Richards (66)
# 20      R        J.Weaver (40)
# 21      R      N.Tropeano (48)
# 22      R     F.Hernandez (70)
# 23      L         W.Miley (81)
# 24   None                 None
# 25      R        T.Walker (47)
# 26      L      G.Gonzalez (63)
# 27      R         T.Roark (54)
# 28      R     S.Strasburg (60)
# 29      R       D.Salazar (79)
# ..    ...                  ...
# 138  None                 None
# 139     R       A.Sanchez (54)
# 140     R        M.Fulmer (49)
# 141     L        D.Norris (58)
# 142     R       J.Berrios (34)
# 143     R       E.Santana (57)
# 144     R        K.Gibson (42)
# 145     L         C.Rodon (61)
# 146     R       J.Shields (53)
# 147     L          C.Sale (69)
# 148     L      R.Detwiler (36)
# 149     R        J.Cotton (48)
# 150     L        S.Manaea (65)
# 151     R       D.Mengden (77)
# 152     L          C.Sale (70)
# 153     R      M.Gonzalez (55)
# 154     L      J.Quintana (16)
# 155     L         C.Rodon (25)
# 156     R        J.Tomlin (63)
# 157     R        C.Kluber (60)
# 158     R     M.Clevinger (53)
# 159     R        M.Fulmer (66)
# 160     L        D.Norris (53)
# 161     L          M.Boyd (24)
# 162     R       J.Berrios (43)
# 163     R       E.Santana (53)
# 164     R        K.Gibson (46)
# 165     L       R.Merritt (61)
# 166     R         T.Bauer (55)
# 167     R        J.Tomlin (61)
#
# [168 rows x 32 columns]

# %%
############################################################################

# %%
#Bokeh imports
from bokeh.io import output_notebook, show
from bokeh.models import HoverTool
from bokeh.models import ColumnDataSource
from bokeh.plotting import figure
from bokeh.io import output_notebook
output_notebook()

# %%
#Develop hover plot for hits and runs
source = ColumnDataSource(
        data=dict(
            x=df['R'],
            y=df['H'],
            desc=df['Opp'],
        )
    )

hover = HoverTool(
        tooltips=[
            ("index", "$index"),
            ("(x,y)", "($x, $y)"),
            ("desc", "@desc"),
        ]
    )

p = figure(plot_width=900, plot_height=900, tools=[hover], title="Mouse over the dots")

p.circle('x', 'y', size=20, source=source)

show(p)
# Out:
#     <div class="plotdiv" id="56742329-c957-46b6-becc-3ff99022a799"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("56742329-c957-46b6-becc-3ff99022a799");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '56742329-c957-46b6-becc-3ff99022a799' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"7ccee21e-0acc-42e5-82a2-b64a43fc926b":{"roots":{"references":[{"attributes":{"below":[{"id":"f5d935b0-10e4-45b1-af34-cb316d6a23d4","type":"LinearAxis"}],"left":[{"id":"13f64a68-c9f3-4a15-8a80-0c6fd544d62a","type":"LinearAxis"}],"plot_height":900,"plot_width":900,"renderers":[{"id":"f5d935b0-10e4-45b1-af34-cb316d6a23d4","type":"LinearAxis"},{"id":"d80a143a-3d3f-4325-9b4d-ad5e8f114ac1","type":"Grid"},{"id":"13f64a68-c9f3-4a15-8a80-0c6fd544d62a","type":"LinearAxis"},{"id":"7d3ece0b-5981-4405-aba5-1556c5f54d3a","type":"Grid"},{"id":"8e381ef7-19cb-4e6c-bd3f-949c6fedb5ff","type":"GlyphRenderer"}],"title":"Mouse over the dots","tool_events":{"id":"ab3d502c-eee3-45c6-8a35-bc87eda53d93","type":"ToolEvents"},"tools":[{"id":"e461e108-c9f6-4a9e-926e-2d1150fd2bbc","type":"HoverTool"}],"x_range":{"id":"3068d61f-8095-4bd7-a4a9-966b0f097ea0","type":"DataRange1d"},"y_range":{"id":"61fedb0d-86a7-43a2-9967-48cbbc6a693c","type":"DataRange1d"}},"id":"9d91009f-a3ea-48e3-8740-db628bd76712","subtype":"Figure","type":"Plot"},{"attributes":{"below":[{"id":"8df152a