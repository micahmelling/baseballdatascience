# %%
import numpy as np
from pandas import Series,DataFrame
import pandas as pd
import csv
import matplotlib.pyplot as plt
import matplotlib
matplotlib.style.use('ggplot')
# %matplotlib inline

# %%
import os
os.chdir('C:\Users\Micah\Desktop\Baseball Data Science\Attendance Prediction')

# %%
team_stats = pd.read_csv('offensive_stats.csv')

# %%
team_stats.head()
# Out:
#   Quartile  Runs  Hits  Home_Runs  Stolen_Bases  Strike_Outs
# 0    Third   829  1531        161           126          953
# 1    Third   787  1530        147            93         1028
# 2    First   711  1404        158            71         1022
# 3    Third   864  1574        236            93         1024
# 4   Second   691  1447        158           116         1001

# %%
from pandas.tools.plotting import radviz

# %%
fig, ax = plt.subplots()
fig.set_size_inches(11.7, 8.27)
radviz(team_stats, 'Quartile')

# %%
team_stats1 = pd.read_csv('pitching_stats.csv')

# %%
team_stats1.head()
# Out:
#   Quartile  Errors   ERA  Walks  Strikeouts
# 0    Third     123  4.52    605        1050
# 1    Third     106  4.49    630        1091
# 2    First     106  4.79    624         877
# 3    Third     134  5.00    662         846
# 4   Second     103  4.20    525         947

# %%
fig, ax = plt.subplots()
fig.set_size_inches(11.7, 8.27)
radviz(team_stats1, 'Quartile')
